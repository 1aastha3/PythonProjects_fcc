# %%
import pandas as pd
import csv

# %%
df = pd.read_csv('/Users/aasthaprajapati/Downloads/adult.data.csv')

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# Question1 : How many people of each race are represented in this dataset? This should be a Pandas series with race names as the index labels. (race column)

# %% [markdown]
# Method 1

# %%
race_count = pd.Series(
    [df[df.race == 'White'].shape[0], df[df.race == 'Black'].shape[0], df[df.race == 'Asian-Pac-Islander'].shape[0], df[df.race == 'Amer-Indian-Eskimo'].shape[0], df[df.race == 'Other'].shape[0]],
    index = ['White', 'Black','Asian-Pac-Islander','Amer-Indian-Eskimo','Other']
)

# %%
race_count
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# dtype: int64

# %%
df.race.unique()
# Out:
# array(['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo',
#        'Other'], dtype=object)

# %%
df.race.shape[0]
# Out:
# 32561

# %% [markdown]
# Method 2

# %%
race_count2 = df['race'].value_counts()

# %%
race_count2
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %% [markdown]
# Question 2: What is the average age of men?

# %% [markdown]
# Method 1

# %%
df[df.sex=='Male'].age.mean()
# Out:
# 39.43354749885268

# %% [markdown]
# Method 2

# %%
df1 = round(df.groupby('sex')['age'].mean()['Male'],1)

# %%
df1
# Out:
# 39.4

# %% [markdown]
# Question 3: What is the percentage of people who have a Bachelor's degree?

# %%
round(df[df.education=='Bachelors'].shape[0]/df.education.shape[0]*100,1)
# Out:
# 16.4

# %%
round(df['education'].value_counts()['Bachelors']/df.shape[0]*100,1)
# Out:
# 16.4

# %% [markdown]
# Question 4 : What percentage of people with advanced education (Bachelors, Masters, or Doctorate) make more than 50K?

# %%
round(df[(df.salary == '>50K') & ((df.education == 'Masters') | (df.education == 'Bachelors') | (df.education == 'Doctorates'))].shape[0]/((df.education == 'Masters') | (df.education == 'Bachelors') | (df.education == 'Doctorates')).shape[0]*100,1)
# Out:
# 9.8

# %%
df.shape[0]
# Out:
# 32561

# %%
df.education.shape[0]
# Out:
# 32561

# %%
higher_education = df.loc[df['education'].isin(['Bachelors', 'Masters', 'Doctorates'])]

# %%
lower_education = df.loc[~df['education'].isin(['Bachelors', 'Masters', 'Doctorates'])]

# %%
rich_highEducation = round(100.0 * (higher_education['salary'] == '>50K').sum() / len(higher_education), 1 )

# %%
rich_highEducation
# Out:
# 44.9

# %% [markdown]
# Question 5: What percentage of people without advanced education make more than 50K?

# %%
rich_lowEducation = round((low_education['salary']=='>50K').sum()/len(highEducation)*100,1)

# %%
rich_lowEducation
# Out:
# 65.9

# %% [markdown]
# Question 6:What is the minimum number of hours a person works per week?

# %%
df['hours-per-week'].min()
# Out:
# 1

# %% [markdown]
# Question 7 : What percentage of the people who work the minimum number of hours per week have a salary of more than 50K?

# %%
minhoursworkers = df.loc[df['hours-per-week']==df['hours-per-week'].min()]

# %%
minhoursworkers
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 189     58         State-gov  109567     Doctorate             16
# 1036    66      Self-emp-inc  150726           9th              5
# 1262    69                 ?  195779     Assoc-voc             11
# 5590    78                 ?  363134       HS-grad              9
# 5632    45                 ?  189564       Masters             14
# 5766    62                 ?   97231  Some-college             10
# 5808    76                 ?  211574          10th              6
# 8447    67                 ?  244122     Assoc-voc             11
# 9147    75                 ?  260543          10th              6
# 11451   27           Private  147951       HS-grad              9
# 19337   72                 ?   76860       HS-grad              9
# 19750   23           Private   72887       HS-grad              9
# 20072   65                 ?   76043       HS-grad              9
# ...

# %%
round((minhoursworkers['salary']=='>50K').sum()/len(minhoursworkers)*100,1)
# Out:
# 10.0

# %%
rich_min_hours_workers = round((minhoursworkers['salary']=='>50K').sum()/minhoursworkers*100,1)
rich_min_hours_workers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/roperator.py in rtruediv(left, right)
# ...

# %%
(minhoursworkers['salary']=='>50K').sum()
# Out:
# 2

# %% [markdown]
# Question 8 : What country has the highest percentage of people that earn >50K and what is that percentage?

# %%
salary_nation = df.loc[df.groupby('native-country')['salary'].value_counts()['United-States']]
salary_nation
# Out:
#        age workclass  fnlwgt  education  education-num marital-status  \
# 21999   25   Private   69847  Bachelors             13  Never-married
# 7171    24   Private  209770  Bachelors             13  Never-married
#
#            occupation   relationship                race     sex  \
# 21999    Adm-clerical      Own-child  Asian-Pac-Islander  Female
# 7171   Prof-specialty  Not-in-family               White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 21999             0             0              40  United-States  <=50K
# 7171              0             0               8  United-States  <=50K

# %%
df['native-country'].unique()
# Out:
# array(['United-States', 'Cuba', 'Jamaica', 'India', '?', 'Mexico',
#        'South', 'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany',
#        'Iran', 'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia',
#        'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal',
#        'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala',
#        'China', 'Japan', 'Yugoslavia', 'Peru',
#        'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago',
#        'Greece', 'Nicaragua', 'Vietnam', 'Hong', 'Ireland', 'Hungary',
#        'Holand-Netherlands'], dtype=object)

# %%
df.salary.unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
df.salary.value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: salary, dtype: int64

# %%
salary_nation = df[(df['salary']=='>50K')]['native-country'].value_counts()

# %%
salary_nation
# Out:
# United-States         7171
# ?                      146
# Philippines             61
# Germany                 44
# India                   40
# Canada                  39
# Mexico                  33
# England                 30
# Italy                   25
# Cuba                    25
# Japan                   24
# Taiwan                  20
# China                   20
# Iran                    18
# South                   16
# Puerto-Rico             12
# Poland                  12
# France                  12
# Jamaica                 10
# El-Salvador              9
# Greece                   8
# Cambodia                 7
# Hong                     6
# Yugoslavia               6
# Ireland                  5
# Vietnam                  5
# Portugal                 4
# Haiti                    4
# Ecuador                  4
# Thailand                 3
# Hungary                  3
# Guatemala                3
# Scotland                 3
# Nicaragua                2
# ...

# %%
highest_earning_country = None
highest_earning_country_percentage = 0.0

# %%
for country, data in df.groupby('native-country'):
    percentage = (data['salary'] == '>50K').sum() / data['salary'].count()
    if highest_earning_country_percentage < percentage:
        highest_earning_country_percentage = percentage
        highest_earning_country = country
highest_earning_country_percentage = round(100 * highest_earning_country_percentage,1)

# %%
highest_earning_country
# Out:
# 'Iran'

# %%
highest_earning_country_percentage
# Out:
# 4190.0

# %%
indiacount= df.loc[df['native-country']=='India']

# %%
indiacount
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 11      30         State-gov  141297   Bachelors             13
# 892     28           Private  164170   Assoc-voc             11
# 968     48           Private  164966   Bachelors             13
# 1029    48      Self-emp-inc  138370     Masters             14
# 1095    22  Self-emp-not-inc  361280   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 30152   48           Private  119471   Doctorate             16
# 30833   25           Private  110978  Assoc-acdm             12
# 30871   26           Private  160261     Masters             14
# 31327   38         State-gov  125499   Bachelors             13
# 31357   23           Private  143003     Masters             14
#
#               marital-status       occupation   relationship  \
# 11        Married-civ-spouse   Prof-specialty        Husband
# 892       Married-civ-spouse     Adm-clerical           Wife
# ...

# %%
rich_india = df[(df['salary']=='>50K') & (df['native-country']=='India')]['occupation'].value_counts().keys()[0]

# %% [markdown]
# Question 9: Identify the most popular occupation for those who earn >50K in India.

# %%
rich_india
# Out:
# 'Prof-specialty'

# %% [markdown]
# CODE CHECKS

# %%
average_age_men = round(df[df.sex=='Male'].age.mean(),1)

# %%
average_age_men
# Out:
# 39.4

# %%
 race_count = df['race'].value_counts()

# %%
race_count
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
percentage_bachelors = round(df[df.education=='Bachelors'].shape[0]/df.education.shape[0]*100,1)

# %%
percentage_bachelors
# Out:
# 16.4

# %%
percentage_bachelors = round( df['education'].value_counts(normalize=True)['Bachelors'] * 100.0, 1 )

# %%
percentage_bachelors
# Out:
# 16.4

# %%
average_age_men = round( df.groupby('sex')['age'].mean()['Male'], 1 )

# %%
average_age_men
# Out:
# 39.4

# %%
higher_education = df.loc[df['education'].isin(['Bachelors', 'Masters', 'Doctorates'])]

# %%
higher_education
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 5       37           Private  284582    Masters             14
# 8       31           Private   45781    Masters             14
# ...    ...               ...     ...        ...            ...
# 32536   34           Private  160216  Bachelors             13
# 32538   38           Private  139180  Bachelors             13
# 32544   31           Private  199655    Masters             14
# 32553   32           Private  116138    Masters             14
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
higher_education =  df.loc[df['education'].isin(['Bachelors', 'Masters', 'Doctorate'])]

# %%
higher_education
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 5       37           Private  284582    Masters             14
# 8       31           Private   45781    Masters             14
# ...    ...               ...     ...        ...            ...
# 32538   38           Private  139180  Bachelors             13
# 32539   71                 ?  287372  Doctorate             16
# 32544   31           Private  199655    Masters             14
# 32553   32           Private  116138    Masters             14
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
 highest_earning_country_percentage = round(df[(df.salary == '>50K') & (df['native-country']==highest_earning_country)].shape[0]/df[df['native-country']=='United-States'].shape[0]*100,1)

# %%
highest_earning_country_percentage
# Out:
# 0.5

# %%
lower_education_rich = round((lower_education['salary']=='>50K').sum()/len(lower_education)*100,1)

# %%
lower_education_rich
# Out:
# 18.3

# %%
lower_education = df.loc[~df['education'].isin(['Bachelors', 'Masters', 'Doctorates'])]

# %%
lower_education
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 10      37           Private  280464  Some-college             10
# ...    ...               ...     ...           ...            ...
# 32556   27           Private  257302    Assoc-acdm             12
# 32557   40           Private  154374       HS-grad              9
# 32558   58           Private  151910       HS-grad              9
# 32559   22           Private  201490       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#               marital-status         occupation   relationship   race     sex  \
# 2                   Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %%
higher_education_rich = round((higher_education['salary']=='>50K').sum()/len(higher_education)*100,1)

# %%
higher_education_rich
# Out:
# 46.5

# %%
lower_education_rich = round(100.0 * (lower_education['salary'] == '>50K').sum() / len(lower_education), 1 )

# %%
lower_education_rich
# Out:
# 18.3

# %%
 higher_education_rich = round(100.0 * (higher_education['salary'] == '>50K').sum() / len(higher_education), 1 )

# %%
higher_education_rich
# Out:
# 46.5

# %%
df.education.value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
highest_earning_country = None
highest_earning_country_percentage = 0.0
    
for country, data in df.groupby('native-country'):
    percentage = (data['salary'] == '>50K').sum() / data['salary'].count()
    if highest_earning_country_percentage < percentage:
        highest_earning_country_percentage = percentage
        highest_earning_country = country
highest_earning_country_percentage = round(100 * highest_earning_country_percentage,1)

# %%
highest_earning_country
# Out:
# 'Iran'

# %%
higher_education_rich = round(100.0 * (higher_education['salary'] == '>50K').sum() / len(higher_education), 1 )

# %%
higher_education_rich
# Out:
# 46.5
